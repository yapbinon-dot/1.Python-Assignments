# %% [markdown]
# # Assignment - 1 - Control structures

# %%
print('Welcome to Assignment-1')
# Out:
# Welcome to Assignment-1

# %%
Num1=10
Num2=30
Add=Num1+Num2
print("Add=",Add)
# Out:
# Add= 40

# %% [markdown]
# # Body Mass INdex

# %%
BMI = float(input("Enter the Body Mass Index:"))

if BMI >= 30:
    print("Category: Very Overweight")
else:
    print("Category: Not very overweight")
# Out:
# Enter the Body Mass Index: 34
# Category: Very Overweight
