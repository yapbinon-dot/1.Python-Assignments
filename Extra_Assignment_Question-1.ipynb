# %% [markdown]
# # Extra_Assingment_Question-1

# %%
print('HOPE AI')
# Out:
# HOPE AI

# %%
Instituion_name = input('Enter your instituion name? :')
# Out:
# Enter your instituion name? : HOPE AI

# %%
name = input('Enter your name:')
# Out:
# Enter your name: Raj

# %%
age = input('Enter your age:')
# Out:
# Enter your age: 15

# %%
School_Name = input('Enter your School Name:')
# Out:
# Enter your School Name: Guru School

# %%
Degree = input('Enter your degree:')
# Out:
# Enter your degree: B.E CSE

# %% [markdown]
# # Addition

# %%
a=43
b=34
add=a+b
print('add=', add)
# Out:
# add= 77

# %% [markdown]
# # Subtraction

# %%
a=43
b=34
sub=a-b
print('sub=', sub)
# Out:
# sub= 9

# %% [markdown]
# # Multiplication

# %%
a=63
b=97
Mul=a*b
print('Mul=', Mul)
# Out:
# Mul= 6111

# %% [markdown]
# # Division

# %%
a=76
b=31
Float_Division=a/b
print('Float_Division=', Float_Division)
# Out:
# Float_Division= 2.4516129032258065

# %% [markdown]
# # Floor Division

# %%
a=76
b=31
Floor_Division=a//b
print('Floor_Division=', Floor_Division)
# Out:
# Floor_Division= 2

# %% [markdown]
# # Modulo

# %%
a=76
b=31
Modulo=a%b
print('Modulo=', Modulo)
# Out:
# Modulo= 14

# %% [markdown]
# # Power

# %%
a=4
b=4
power=a**b
print('power=', power)
# Out:
# power= 256
